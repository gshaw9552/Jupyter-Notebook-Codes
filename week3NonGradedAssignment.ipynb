# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mtcars_data = pd.read_csv("mtcars.csv", index_col = 0, na_values=["??", "????"])
diamond_data = pd.read_csv("diamond.csv", index_col = 0, na_values=["??", "????"])
churn_data = pd.read_csv("churn.csv", index_col = 0, na_values=["??", "????"])
df_cocoa = pd.read_csv("flavors_of_cocoa.csv", index_col = 0, na_values=["??", "????"])

# %%
mtcars_data.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# model
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# model
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
diamond_data.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
churn_data.head()
# Out:
#    customerID tenure        Contract PaperlessBilling  \
# 1  8260-NGFNY    One  Month-to-month               No
# 2  2359-QWQUL     39        One year              Yes
# 3  6598/RFFVI      2        One year               No
# 4  IXSTS-8780      6  Month-to-month              Yes
# 5  2674/MIAHT   Four  Month-to-month              Yes
#
#              PaymentMethod  MonthlyCharges  TotalCharges  gender  \
# 1             Mailed check            25.2         25.20  Female
# 2  Credit card (automatic)           104.7       4134.85  Female
# 3  Credit card (automatic)            19.3         28.30    Male
# 4         Electronic check            90.1        521.30  Female
# 5             Mailed check            80.3        324.20  Female
#
#    SeniorCitizen Partner  ... PhoneService     MultipleLines InternetService  \
# 1            0.0      No  ...           No  No phone service             DSL
# 2            0.0     Yes  ...          Yes                No     Fiber optic
# ...

# %%
df_cocoa.head()
# Out:
#      Company  Bean Origin  Review Date Cocoa Percent Company Location  Rating
# Id
# 1   A. Morin  Agua Grande       2016.0           63%           France    3.75
# 2   A. Morin        Kpime       2015.0           70%           France    2.75
# 3   A. Morin       Atsane       2015.0           70%           France    3.00
# 4   A. Morin        Akata       2015.0           70%           France    3.50
# 5   A. Morin       Quilla       2015.0           70%           France    3.50

# %%
plt.scatter(mtcars_data['mpg'], mtcars_data['wt'], c='red')
plt.title('Scatter Plot of mpg vs wt of the mtcars')
plt.xlabel('mpg')
plt.ylabel('wt')
plt.show()

# %%
sns.boxplot(x=diamond_data["price"], y=diamond_data["cut"])
# Out:
# <Axes: xlabel='price', ylabel='cut'>

# %%
churn_data.isna().sum()
# Out:
# customerID           0
# tenure               0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges      10
# TotalCharges        15
# gender               0
# SeniorCitizen        5
# Partner              0
# Dependents           0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Churn                0
# dtype: int64

# %%
churn_data.describe()
# Out:
#        MonthlyCharges  TotalCharges  SeniorCitizen
# count      247.000000    242.000000     252.000000
# mean        62.473482   2267.953719       0.134921
# std         31.126525   2270.876564       0.342319
# min          3.500000     18.850000       0.000000
# 25%         25.700000    450.687500       0.000000
# 50%         70.300000   1313.025000       0.000000
# 75%         88.325000   3691.187500       0.000000
# max        115.100000   8337.450000       1.000000

# %%
df_cocoa.isnull().sum()
# Out:
# Company             0
# Bean Origin         0
# Review Date         4
# Cocoa Percent       0
# Company Location    0
# Rating              0
# dtype: int64

# %%
df_cocoa["Company Location"].value_counts()
# Out:
# Company Location
# U.S.A.               764
# France               156
# Canada               125
# U.K.                  96
# Italy                 63
# Ecuador               54
# Australia             49
# Belgium               40
# Switzerland           38
# Germany               35
# Austria               26
# Spain                 25
# Colombia              23
# Hungary               22
# Venezuela             20
# Japan                 17
# Brazil                17
# Peru                  17
# Madagascar            17
# New Zealand           17
# Denmark               15
# Vietnam               11
# Scotland              10
# Guatemala             10
# Israel                 9
# Costa Rica             9
# Argentina              9
# Poland                 8
# Lithuania              6
# Honduras               6
# South Korea            5
# Nicaragua              5
# Sweden                 5
# Domincan Republic      5
# Ireland                4
# Netherlands            4
# ...

# %%
df_cocoa.dtypes
# Out:
# Company              object
# Bean Origin          object
# Review Date         float64
# Cocoa Percent        object
# Company Location     object
# Rating              float64
# dtype: object

# %%
df_cocoa["Rating"].max()
# Out:
# 5.0

# %%
df_cocoa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1795 entries, 1 to 1795
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1795 non-null   object
#  1   Bean Origin       1795 non-null   object
#  2   Review Date       1791 non-null   float64
#  3   Cocoa Percent     1795 non-null   object
#  4   Company Location  1795 non-null   object
#  5   Rating            1795 non-null   float64
# dtypes: float64(2), object(4)
# memory usage: 98.2+ KB
